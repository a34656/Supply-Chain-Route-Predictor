# %%
# !pip install openpyxl
# Out:
# ...
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# ...
#   Using cached et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# ...
# WARNING: You are using pip version 22.0.4; however, version 25.3 is available.
# You should consider upgrading via the 'C:\Users\KIIT0001\ai_engine\sales\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd
df = pd.read_excel("data/raw/International_LPI_from_2007_to_2023_0.xlsx", sheet_name= False)

# %%
df.items()
# Out:
# <generator object DataFrame.items at 0x00000273ADBE36D0>

# %%
df_2023 = pd.read_excel("data/raw/International_LPI_from_2007_to_2023_0.xlsx", sheet_name="2018")
# Out:
# c:\Users\KIIT0001\ai_engine\sales\lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
df_2023.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'overall LPI score', 'Unnamed: 3',
#        'Unnamed: 4', 'overall LPI rank', 'Unnamed: 6', 'Unnamed: 7',
#        'Unnamed: 8', 'Customs', 'Unnamed: 10', 'Infrastructure', 'Unnamed: 12',
#        'International shipments', 'Unnamed: 14',
#        'Logistics quality and competence', 'Unnamed: 16',
#        'Tracking and tracing', 'Unnamed: 18', 'Timeliness', 'Unnamed: 20'],
#       dtype='object')
